# %%
#Backpropogation Algorithm

# %%
import numpy as np

# %%
input_layer_neurons=2
hidden_layer_neurons=3
output_neurons=1
print("Number of input layer neurons: ",input_layer_neurons)
print("Number of hidden layer neurons: ",hidden_layer_neurons)
print("Number of output layer neurons: ",output_neurons)
# Out:
# Number of input layer neurons:  2
# Number of hidden layer neurons:  3
# Number of output layer neurons:  1

# %%
wh=np.random.uniform(size=(input_layer_neurons,hidden_layer_neurons))
print("Weights from input layer to hidden layer : \n",wh)
bh=np.random.uniform(size=(1,hidden_layer_neurons))
print("Bias between input and hidden layers : \n",bh)
wout=np.random.uniform(size=(hidden_layer_neurons,output_neurons))
print("Weights from hidden layer to output layer : \n",wout)
bout=np.random.uniform(size=(1,output_neurons))
print("Bias between output and hidden layers : \n",bout)
# Out:
# Weights from input layer to hidden layer :
#  [[0.30275525 0.91031533 0.24516845]
#  [0.7029169  0.29200156 0.45936081]]
# Bias between input and hidden layers :
#  [[0.32847393 0.98592522 0.75740942]]
# Weights from hidden layer to output layer :
#  [[0.44556859]
#  [0.98311282]
#  [0.31232199]]
# Bias between output and hidden layers :
#  [[0.47913926]]

# %%
epoch=7000
lr=0.1
x=np.array(([2,9],[1,5],[3,6]))
y=np.array(([92],[86],[89]))
print(x)
x=x/np.amax(x,axis=0)
x
# Out:
# [[2 9]
#  [1 5]
#  [3 6]]
# array([[0.66666667, 1.        ],
#        [0.33333333, 0.55555556],
#        [1.        , 0.66666667]])

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
def derivatives_sigmoid(x):
    return x*(1-x)

# %%
for i in range(epoch):
    hinp1=np.dot(x,wh)
    hinp=hinp1+bh
    hlayer_act=sigmoid(hinp)
    outinp1=np.dot(hlayer_act,wout)
    outinp=outinp1+bout
    output=sigmoid(outinp)
    
    
    EO=y-output
    outgrad=derivatives_sigmoid(output)
    d_output=EO*outgrad
    EH=d_output.dot(wout.T)
    hiddengrad=derivatives_sigmoid(hlayer_act)
    d_hiddenlayer=EH*hiddengrad
    
    wht+= x.T.dot(d_hiddenlayer)*lr
    wout+=hlayer_act.T.dot(d_output)*lr
    
    
    
    print("Input : \n",str(x))
    print("Actual o/p : \n",str(y))
    print("Predicted o/p : \n",output)
# Out:
# Input :
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual o/p :
#  [[92]
#  [86]
#  [89]]
# Predicted o/p :
#  [[0.99973897]
#  [0.99961017]
#  [0.99972963]]
# Input :
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual o/p :
#  [[92]
#  [86]
#  [89]]
# Predicted o/p :
#  [[0.99974216]
#  [0.99961469]
#  [0.99973292]]
# Input :
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual o/p :
#  [[92]
#  [86]
#  [89]]
# Predicted o/p :
#  [[0.99974527]
#  [0.9996191 ]
#  [0.99973613]]
# Input :
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual o/p :
#  [[92]
#  [86]
#  [89]]
# Predicted o/p :
#  [[0.99974831]
#  [0.99962341]
#  [0.99973926]]
# Input :
#  [[0.66666667 1.        ]
#  [0.33333333 0.55555556]
#  [1.         0.66666667]]
# Actual o/p :
#  [[92]
#  [86]
#  [89]]
# Predicted o/p :
#  [[0.99975128]
#  [0.99962762]
# ...
